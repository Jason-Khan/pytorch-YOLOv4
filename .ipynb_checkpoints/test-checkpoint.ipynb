# %%
from models import Yolov4
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread("./data/dog.jpg")
plt.imshow(img)

# %%
model_input = [[cv2.resize(img, (608, 608))]]
model_input = np.concatenate(model_input, axis=0)
model_input = model_input.transpose(0, 3, 1, 2)
model_input = torch.from_numpy(model_input).div(255.0)
model_input = model_input.to('cuda:0')
model = Yolov4()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-177c9288159c> in <module>
#       1 model_input = [[cv2.resize(img, (608, 608))]]
# ----> 2 model_input = np.concatenate(model_input, axis=0)
#       3 model_input = model_input.transpose(0, 3, 1, 2)
#       4 model_input = torch.from_numpy(model_input).div(255.0)
#       5 model_input = model_input.to('cuda:0')
#
# NameError: name 'np' is not defined
